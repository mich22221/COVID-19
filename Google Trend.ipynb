# %% [markdown]
# <a href="https://colab.research.google.com/github/mich22221/COVID-19/blob/master/Google%20Trend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pytrends

# %%
import pandas as pd                        
from pytrends.request import TrendReq
pytrend = TrendReq()

# %%
pytrend.build_payload(kw_list = ["Economist"])
df = pytrend.interest_over_time()

# %%
df
# Out:
#             Taylor Swift  isPartial
# date
# 2016-01-03            36      False
# 2016-01-10            32      False
# 2016-01-17            30      False
# 2016-01-24            28      False
# 2016-01-31            28      False
# ...                  ...        ...
# 2020-11-22            16      False
# 2020-11-29            13      False
# 2020-12-06            31      False
# 2020-12-13            29      False
# 2020-12-20            19      False
#
# [260 rows x 2 columns]

# %%
df.reset_index().plot(x="date", y="Economist", figsize=(120, 10), kind ="line")
